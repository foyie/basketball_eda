# %%
import numpy as np 
import pandas as pd 

import streamlit as st 
import base64

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_stats_per_game.html',header=0)
df[0]
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          Rk     Season         Lg        Age         Ht         Wt
# 1           1    2022-23        NBA        NaN        NaN        NaN
# 2           2    2021-22        NBA       26.1        6-6        215
# 3           3    2020-21        NBA       26.1        6-6        217
# 4           4    2019-20        NBA       26.1        6-6        218
# ..        ...        ...        ...        ...        ...        ...
# 79         73    1950-51        NBA        NaN        NaN        NaN
# 80         74    1949-50        NBA        NaN        NaN        NaN
# 81         75    1948-49        BAA        NaN        NaN        NaN
# 82         76    1947-48        BAA        NaN        NaN        NaN
# 83         77    1946-47        BAA        NaN        NaN        NaN
#
#    Unnamed: 6 Per Game Per Game.1 Per Game.2  ... Per Game.15 Shooting  \
# ...
